# %%
print("Hello World")
# Out:
# Hello World

# %%
def f(x):
    return x**2

# %%
[f(x) for x in range(10)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
for i in range(8):
    printb(i)

# %%
print("hurray")
# Out:
# hurray
